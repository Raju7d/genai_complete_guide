# %% [markdown]
# # Word2Vec
#
# -> refer data_vectorization.ipynb

# %%
# https://drive.google.com/file/d/1lbtAwzE7l0otXYFDtGUKKWzI83bD5D5H/view?usp=drive_link

# %%
# %pip install --upgrade gensim --user

# %%
import numpy as np
import pandas as pd
import gensim
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess # before sending text to word2vec we need to do preprocessing for cleaning and all
import nltk
nltk.download('punkt')

# %%
import os

story = []
f = open(r"C:\Users\virub\OneDrive\Desktop\RAJU FILES\Gen AI Complete Guide\genai_complete_guide\2. Data Vectorization or Representation\Resources\test.txt")
corpus = f.read()
raw_sent = sent_tokenize(corpus)
print(raw_sent)
for sent in raw_sent:
    story.append(simple_preprocess(sent))

# %%
story

# %%
len(story)
# Out:
# 8602

# %%
story[0]
# Out:
# ['game',
#  'of',
#  'thrones',
#  'book',
#  'one',
#  'of',
#  'song',
#  'of',
#  'ice',
#  'and',
#  'fire',
#  'by',
#  'george',
#  'martin',
#  'prologue',
#  'we',
#  'should',
#  'start',
#  'back',
#  'gared',
#  'urged',
#  'as',
#  'the',
#  'woods',
#  'began',
#  'to',
#  'grow',
#  'dark',
#  'around',
#  'them']

# %%
# initialize the model

model = gensim.models.word2vec(
    window=10,
    min_count=2
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # initialize the model
# ----> 3 model = gensim.models.word2vec(
#       4     window=10,
#       5     min_count=2
#       6 )
#
# NameError: name 'gensim' is not defined
